# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/fifa_eda.csv")

# %%
df
# Out:
#            ID                Name  Age Nationality  Overall  Potential  \
# 0      158023            L. Messi   31   Argentina       94         94
# 1       20801   Cristiano Ronaldo   33    Portugal       94         94
# 2      190871           Neymar Jr   26      Brazil       92         93
# 3      193080              De Gea   27       Spain       91         93
# 4      192985        K. De Bruyne   27     Belgium       91         92
# ...       ...                 ...  ...         ...      ...        ...
# 18202  238813        J. Lundstram   19     England       47         65
# 18203  243165  N. Christoffersson   19      Sweden       47         63
# 18204  241638           B. Worman   16     England       47         67
# 18205  246268      D. Walker-Rice   17     England       47         66
# 18206  246269           G. Nugent   16     England       46         66
#
#                       Club     Value   Wage Preferred Foot  \
# ...

# %%
###The tallest 5 players
df[['Name','Height']].sort_values(by='Height',ascending=False).iloc[:5]
# Out:
#                       Name    Height
# 11614              T. Holý  6.750000
# 17927            D. Hodzic  6.750000
# 4189   V. Milinković-Savić  6.666667
# 11403           A. Noppert  6.666667
# 16923            S. Brolin  6.666667

# %%
##Mean, Meadian of Age
df['Age'].mean(),df['Age'].median()
# Out:
# (np.float64(25.122205745043114), 25.0)

# %%
## The smallest Weight
df[['Name','Weight','Age']].sort_values(by='Weight').iloc[:2]
# Out:
#                 Name  Weight  Age
# 17157   K. Yamaguchi   110.0   23
# 13338  B. Al Mutairi   110.0   28

# %%
## The smallest Weight
min_weigth=df['Weight'].min()
df[df['Weight']==min_weigth]  #Slicing
# Out:
#            ID           Name  Age   Nationality  Overall  Potential  \
# 13338  235600  B. Al Mutairi   28  Saudi Arabia       62         62
# 17157  242566   K. Yamaguchi   23         Japan       55         61
#
#                   Club  Value  Wage Preferred Foot  International Reputation  \
# 13338         Al Batin  240.0   3.0           Left                       1.0
# 17157  Shonan Bellmare  120.0   1.0          Right                       1.0
#
#        Skill Moves Position  Joined Contract Valid Until    Height  Weight  \
# 13338          2.0       LB    2011           2021-01-01  5.500000   110.0
# 17157          3.0       CF    2018           2021-01-01  5.083333   110.0
#
#        Release Clause
# 13338           396.0
# 17157           174.0

# %%
df_org=pd.read_csv('/content/fifa_eda.csv')

# %%
df['Name']=df_org['Name']

# %%
##Christiano Ronaldo Position
df[df['Name']=='Cristiano Ronaldo'][['Name','Position']]
# Out:
#                 Name Position
# 1  Cristiano Ronaldo       ST

# %%
df.head()
# Out:
#        ID               Name  Age Nationality  Overall  Potential  \
# 0  158023           L. Messi   31   Argentina       94         94
# 1   20801  Cristiano Ronaldo   33    Portugal       94         94
# 2  190871          Neymar Jr   26      Brazil       92         93
# 3  193080             De Gea   27       Spain       91         93
# 4  192985       K. De Bruyne   27     Belgium       91         92
#
#                   Club     Value   Wage Preferred Foot  \
# 0         FC Barcelona  110500.0  565.0           Left
# 1             Juventus   77000.0  405.0          Right
# 2  Paris Saint-Germain  118500.0  290.0          Right
# 3    Manchester United   72000.0  260.0          Right
# 4      Manchester City  102000.0  355.0          Right
#
#    International Reputation  Skill Moves Position  Joined  \
# 0                       5.0          4.0       RF    2004
# 1                       5.0          5.0       ST    2018
# ...

# %%
##Avg Value of all player per year (joined column)
df.groupby('Joined')[['Value']].mean().sort_values(by='Value',ascending=False)
# Out:
#                Value
# Joined
# 2004    10415.833333
# 2005     5544.705882
# 2008     5377.924528
# 2010     5240.839695
# 2011     4868.241206
# 2007     4730.789474
# 2013     4181.320961
# 2012     3840.988201
# 2014     3549.077017
# 2009     3468.269231
# 2015     3335.755988
# 2016     2511.245432
# 2002     2351.250000
# 2017     2125.398374
# 2018     1913.759519
# 2006     1208.055556
# 2003     1148.076923
# 2001      237.500000
# 1991      160.000000
# 2000      110.000000
# 1998      106.666667
# 1999       40.000000

# %%
#Count Players in Clubs
df.groupby('Club').count()['Name'].sort_values(ascending=False)
# Out:
# Club
# AS Monaco              33
# Real Madrid            33
# Arsenal                33
# FC Barcelona           33
# Fortuna Düsseldorf     33
#                        ..
# Atlético Paranaense    20
# Vitória                20
# Limerick FC            19
# Sligo Rovers           19
# Derry City             18
# Name: Name, Length: 651, dtype: int64

# %%
#Count Players in Clubs (by default descending)
dfC1=pd.DataFrame(df['Club'].value_counts()).reset_index().rename(columns={'Count1':'Club Name1'})

# %%
dfC1
# Out:
#                     Club  count
# 0               RC Celta     33
# 1                Everton     33
# 2            Valencia CF     33
# 3      Borussia Dortmund     33
# 4    TSG 1899 Hoffenheim     33
# ..                   ...    ...
# 646             Botafogo     20
# 647              Vitória     20
# 648         Sligo Rovers     19
# 649          Limerick FC     19
# 650           Derry City     18
#
# [651 rows x 2 columns]

# %%
df[df['Club'].isna()]
# Out:
#            ID            Name  Age Nationality  Overall  Potential Club  \
# 452    207439      L. Paredes   24   Argentina       80         85  NaN
# 538    156713    A. Granqvist   33      Sweden       80         80  NaN
# 568    229909        A. Lunev   26      Russia       79         81  NaN
# 677    187347    I. Smolnikov   29      Russia       79         79  NaN
# 874    187607       A. Dzyuba   29      Russia       78         78  NaN
# ...       ...             ...  ...         ...      ...        ...  ...
# 17197  245164        V. Kaith   21       India       55         64  NaN
# 17215  243131        K. Taimi   26     Finland       55         57  NaN
# 17339  233526        S. Passi   23       India       54         63  NaN
# 17436  236452  D. Lalhlimpuia   20       India       54         67  NaN
# 17539  234508        C. Singh   21       India       53         62  NaN
#
#        Value  Wage Preferred Foot  International Reputation  Skill Moves  \
# ...

# %%
##How MAny unique clubs including NANs
len(df['Club'].unique())
# Out:
# 652

# %%
##How MAny unique clubs without NANs
df['Club'].nunique()
# Out:
# 651

# %%
##Top 5 common positions
df['Position'].value_counts()[:5]
# Out:
# Position
# ST    2154
# GK    2027
# CB    1779
# CM    1395
# LB    1372
# Name: count, dtype: int64

# %%
#Top 5 common nationalities
df.groupby('Nationality').count()['ID'].sort_values(ascending=False).head(5)
# Out:
# Nationality
# England      1662
# Germany      1198
# Spain        1072
# Argentina     937
# France        914
# Name: ID, dtype: int64

# %%
##Print the Egyptian Players
df[df['Nationality']=='Egypt']
# Out:
#            ID            Name  Age Nationality  Overall  Potential  \
# 26     209331        M. Salah   26       Egypt       88         89
# 752    226078       Trezeguet   23       Egypt       78         80
# 959    213051       M. Elneny   25       Egypt       77         79
# 1517   210648       A. Hegazi   27       Egypt       76         78
# 2241   210259       A. Hassan   25       Egypt       74         78
# 2259   219740         Kahraba   24       Egypt       74         79
# 2334   233601        R. Sobhi   21       Egypt       74         79
# 3310   191005   A. Elmohamady   30       Egypt       72         72
# 3616   233600        A. Warda   24       Egypt       72         75
# 3929   212469       A. Ghazal   26       Egypt       72         75
# 4044   229404        A. Tarek   26       Egypt       71         74
# 4217   170828       Shikabala   32       Egypt       71         71
# 4504   197300      A. El Said   32       Egypt       71         71
# ...

# %%
##How Many Players in 2018 with Skill moves =2
df[(df['Joined']==2018)& (df['Skill Moves']==2)].count()['Name']
# Out:
# np.int64(3295)

# %%
##How many players whose name starts with 'M'
df['Name']=df['Name'].str.lower()
len(df['Name'].str.startswith('m'))
# Out:
# 18207

# %%
##Finding the correlation between International Reputation & Wage
df[['International Reputation','Wage']].corr()
#THIS MEANS THAT THE CORRELATION IS STRONG
# Out:
#                           International Reputation      Wage
# International Reputation                  1.000000  0.668635
# Wage                                      0.668635  1.000000

# %%
#Checking that no duplicates
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Distribution of Player Overall Ratings by Number of Players
df['Overall'].hist(bins=20)
plt.xlabel("Overall Score")
plt.ylabel("Frequency")
plt.title("Distribution of Overall Scores")

plt.show()

# %%
(df['Nationality']=='France').sum()
# Out:
# np.int64(914)

# %%
df['Nationality'].value_counts().head(10).plot(kind='bar')
plt.xlabel("Countries")
plt.ylabel("Number of Players")
plt.title("Top 10 Countries in Number of Players")
# Out:
# Text(0.5, 1.0, 'Top 10 Countries in Number of Players')

# %%
#Discribes the overall performace for players accourding to age
#We can find that the peek of the overall performace is in the 30s and this decreases while age is increasing
df.plot.scatter(x='Age', y='Overall')
# Out:
# <Axes: xlabel='Age', ylabel='Overall'>
